# %% [markdown]
# https://www.kaggle.com/datasets/ultimus/football-salaries-dataset?select=raw_wages.csv

# %%
import pandas as pd
pd.set_option('display.columns',50)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 import pandas as pd
# ----> 2 pd.set_option('display.columns',50)
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#
# File ~\anaconda3\Lib\site-packages\pandas\_config\config.py:261, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     260 def __call__(self, *args, **kwds) -> T:
# --> 261     return self.__func__(*args, **kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\_config\config.py:156, in _set_option(*args, **kwargs)
#     153     raise TypeError(f'_set_option() got an unexpected keyword argument "{kwarg}"')
#     155 for k, v in zip(args[::2], args[1::2]):
# --> 156     key = _get_single_key(k, silent)
#     158     o = _get_registered_option(key)
#     159     if o and o.validator:
#
# ...

# %%
df = pd.read_csv('./raw_wages.csv')
# Out:
#                                    Name  \
# 0       Cristiano Ronaldo - Portuguese
# 1       Karim Benzema - French
# 2       Neymar - Brazilian
# 3       Ezri Konsa - English
# 4       Kylian Mbappé - French
# ...                                 ...
# 40786   - -
# 40787   - -
# 40788   - -
# 40789   - -
# 40790   - -
#
#                                             Club  \
# 0       Al-Nassr (KSA) - Roshn Saudi League
# 1       Al-Ittihad - Roshn Saudi League
# 2       Al-Hilal (KSA) - Roshn Saudi League
# 3       Al-Hilal (KSA) - Roshn Saudi League
# 4       Paris Saint-Germain - Ligue 1 Uber Eats
# ...                                          ...
# 40786   -
# 40787   -
# 40788   -
# 40789   -
# 40790   -
#
#                                                 Division  \
# 0       Roshn Saudi League                           ...
# 1       Roshn Saudi League                           ...
# 2       Roshn Saudi League                           ...
# ...
